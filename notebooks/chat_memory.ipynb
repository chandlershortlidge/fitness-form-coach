# %%
# import os 
# from dotenv import load_dotenv
# from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
# from langchain_core.chat_history import InMemoryChatMessageHistory
# from langchain_core.runnables.history import RunnableWithMessageHistory
# from langchain_openai import ChatOpenAI
# from langchain_core.output_parsers import StrOutputParser

# import textwrap

# from chat_memory import get_chat_history, last_n_messages

# %%
# load_dotenv()
# api_key = os.getenv('OPENAI_API_KEY')

# %%
# prompt = ChatPromptTemplate.from_messages([
#     ("system", "you are a helpful fitness coach. answer questions about form, strength and hypertorphy."),
#     MessagesPlaceholder(variable_name="history"),
#     ("human", "{query}")
# ])

# llm = ChatOpenAI(model='gpt-4o')

# output_parser = StrOutputParser()

# chain = prompt | llm | output_parser

# chain_with_history = RunnableWithMessageHistory(
#     chain,
#     get_session_history=get_chat_history,
#     input_messages_key="query",
#     history_messages_key="history"

# )

# response = chain_with_history.invoke(
#     {"query": "what's good grip for bench press?"},
#     config={"configurable": {"session_id": "test_123"}}
# )

# print(textwrap.fill(response))
# Out:
# A good grip for the bench press involves positioning your hands in a
# way that optimizes both safety and performance. Here are some key
# considerations to ensure an effective grip:  1. **Hand Position**:
# - **Standard Grip**: Place your hands slightly wider than shoulder-
# width. This is the most typical grip and provides a balanced emphasis
# on the chest, shoulders, and triceps.    - **Narrow/Close Grip**:
# Position your hands closer together. This variation emphasizes the
# triceps more and can be safer for individuals with shoulder concerns.
# - **Wide Grip**: Position your hands wider than standard, which can
# place more emphasis on the chest but may also increase the risk of
# shoulder strain if not executed with proper form.  2. **Thumb Position
# (Grip Type)**:    - **Full Grip/Thumbs Around**: Wrap your thumbs
# around the bar to secure it fully. This is the safest grip to prevent
# the bar from slipping.    - **Suicide/False Grip**: Your thumbs lie
# alongside your fingers on the same side of the bar. While some lifters
# use this grip to reduce wrist strain, it increases the risk of the bar
# slipping, so caution is needed.  3. **Wrist Position**:    - Keep your
# wrists straight and stacked directly over your forearms. Avoid letting
# them bend backward excessively to minimize strain and promote better
# bar control.  4. **Bar Location**:    - The bar should sit in the base
# of your palm, near the wrist, to allow for a more stable and powerful
# lift.  5. **Engagement**:    - Squeeze the bar tightly. A strong grip
# can help activate more muscle fibers, providing better control and
# potentially increasing the amount of weight you can lift.  Remember to
# always lift within your limits, use proper form, and consider having a
# spotter for safety, especially as you work with heavier weights.

# %%
# response = chain_with_history.invoke(
#     {"query": "what exercise was I asking about?"},
#     config={"configurable": {"session_id": "test_123"}}
# )

# print(textwrap.fill(response))
# Out:
# You were asking about grip technique for the bench press.

# %%
# for message in last_n_messages("test_123", 2):
#     print(message.type)
#     print(textwrap.fill(message.content))
# Out:
# human
# what exercise was I asking about?
# ai
# You were asking about grip technique for the bench press.
