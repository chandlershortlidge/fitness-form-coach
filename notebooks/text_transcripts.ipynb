# %% [markdown]
# ## PDF: EFFECTS OF GRIP WIDTH ON MUSCLE STRENGTH AND ACTIVATION IN THE LAT PULL-DOWN
# - VIDAR ANDERSEN,1 MARIUS S. FIMLAND,2,3 ESPEN WIIK,1 ANDERS SKOGLUND,1 AND
# ATLE H. SAETERBAKKEN

# %%
import fitz #pymuPDF
import json
from functions import write_json, read_json, clean_and_save_transcript, write_documnent_metadata, get_PDF_text

# %%
grip_width_text = get_PDF_text("/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/data/articles/effects_of_grip_width_on_muscle_strength_and.35.pdf")

# %%
grip_width_metadata = write_documnent_metadata(title="EFFECTS OF GRIP WIDTH ON MUSCLE STRENGTH AND ACTIVATION IN THE LAT PULL-DOWN", 
                                               author="VIDAR ANDERSEN,1 MARIUS S. FIMLAND,2,3 ESPEN WIIK,1 ANDERS SKOGLUND,1 AND ATLE H. SAETERBAKKEN", 
                                               exercise_type="lat_pull_down", difficulty="advanced", text=grip_width_text)

grip_width_metadata
# Out:
# {'title': 'EFFECTS OF GRIP WIDTH ON MUSCLE STRENGTH AND ACTIVATION IN THE LAT PULL-DOWN',
#  'author': 'VIDAR ANDERSEN,1 MARIUS S. FIMLAND,2,3 ESPEN WIIK,1 ANDERS SKOGLUND,1 AND ATLE H. SAETERBAKKEN',
#  'exercise_type': 'lat_pull_down',
#  'difficulty': 'advanced',
# ...

# %%
grip_width_json = write_json("/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/data/transcripts/grip_width_lat_pulldown.json", grip_width_metadata)

# %%
lat_pulldown = "/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/data/transcripts/grip_width_lat_pulldown.json"
clean_grip_width_lat_pulldown = clean_and_save_transcript(lat_pulldown, "/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/data/processed/cleaned_grip_width_lat_pulldown.json")
clean_grip_width_lat_pulldown

# %%
read_json("/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/data/processed/cleaned_grip_width_lat_pulldown.json")
# Out:
# {'title': 'EFFECTS OF GRIP WIDTH ON MUSCLE STRENGTH AND ACTIVATION IN THE LAT PULL-DOWN',
#  'author': 'VIDAR ANDERSEN,1 MARIUS S. FIMLAND,2,3 ESPEN WIIK,1 ANDERS SKOGLUND,1 AND ATLE H. SAETERBAKKEN',
#  'exercise_type': 'lat_pull_down',
#  'difficulty': 'advanced',
# ...
