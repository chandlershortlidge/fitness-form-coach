# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")

# %%
import json
from functions import write_json, split_text_add_metadata, read_json, split_text_add_TEXT_metadata, base_encoder
from functions import clean_classification_text

import langchain
import langchain_openai
import textwrap

from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.chat_history import InMemoryChatMessageHistory
from langchain_core.output_parsers import StrOutputParser
from langchain_text_splitters import RecursiveCharacterTextSplitter 
from langchain_core.documents import Document

# %% [markdown]
# ## Jeff Nippard: Overhead Press transcript

# %%
jeff_ohp = "/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/data/processed/cleaned_nippard_ohp_dict"
jeff_ohp_chunked = split_text_add_metadata(jeff_ohp)
jeff_ohp_chunked
# Out:
# [Document(metadata={'video_id': '_RlRDWO2jfg', 'title': 'Build Bigger Shoulders With Perfect Training Technique (The Overhead Press)', 'author': 'Jeff Nippard', 'difficulty': 'intermediate', 'exercise_type': 'overhead_press'}, page_content="Okay, welcome everyone to a new episode of Technique Tuesday. This week, we're going to be looking at how to perform the overhead barbell press, or OHP, with perfect technique. With this movement, we're performing shoulder flexion, basically lifting your arm up overhead, which will be handled by the anterior or front deltoid and, to a lesser degree, the clavicular or upper head of the pecs. We'll also be performing elbow extension, which will hit all three heads of the triceps, and when viewed from the back, you can see that there will be scapular upward rotation occurring, handled by the upper traps. I like the overhead press for two main reasons. First, being a basic multi-joint barbell movement, it allows for a good deal of progressive overload, although it usually does take longer to gain strength on than other exercises, so be patient. Second, it is a great general strength-building exercise that goes through a huge range of motion, nearly 180 degrees of shoulder flexion. However,"),
#  Document(metadata={'video_id': '_RlRDWO2jfg', 'title': 'Build Bigger Shoulders With Perfect Training Technique (The Overhead Press)', 'author': 'Jeff Nippard', 'difficulty': 'intermediate', 'exercise_type': 'overhead_press'}, page_content="strength on than other exercises, so be patient. Second, it is a great general strength-building exercise that goes through a huge range of motion, nearly 180 degrees of shoulder flexion. However, there is one thing that I don't love about the overhead press, and that is that it is quite front deltoid dominant. One 2013 study comparing four shoulder press variations found that dumbbell presses were better than barbell presses for targeting the side delts, and in both cases, doing your presses standing rather than sitting was better for the side delts. So, if growing the side delt is the main goal, in addition to a lateral raise, you may want to include a dumbbell press. However, the range of motion may be cut shorter here, especially as you go heavier, as the bulky head of the dumbbell might start hitting your shoulders on the way down, ending the range of motion. In practice, I think it's smart to combine and periodically vary exercises, and while it isn't perfect on its own, I do"),
#  Document(metadata={'video_id': '_RlRDWO2jfg', 'title': 'Build Bigger Shoulders With Perfect Training Technique (The Overhead Press)', 'author': 'Jeff Nippard', 'difficulty': 'intermediate', 'exercise_type': 'overhead_press'}, page_content="might start hitting your shoulders on the way down, ending the range of motion. In practice, I think it's smart to combine and periodically vary exercises, and while it isn't perfect on its own, I do still like the overhead press as a core, sort of bread-and-butter, vertical pressing movement. Because the OHP involves multiple joints and uses a large range of motion, generally speaking, it should be loaded with moderate to heavy weight, somewhere in the 5 to 10 rep zone. You want to set up the bar in a squat rack at the same height you would for a squat, somewhere around armpit height. You want to unrack the weight by gripping the bar with a slightly wider than shoulder-width grip, so your hands are just outside your shoulders. Get your elbows underneath the bar while slightly bending the knees and hips and stand up straight, lifting the bar up off the rack. Take two to three steps back and firmly plant your feet with a roughly shoulder-width stance and a slight 15-degree foot flare."),
#  Document(metadata={'video_id': '_RlRDWO2jfg', 'title': 'Build Bigger Shoulders With Perfect Training Technique (The Overhead Press)', 'author': 'Jeff Nippard', 'difficulty': 'intermediate', 'exercise_type': 'overhead_press'}, page_content="knees and hips and stand up straight, lifting the bar up off the rack. Take two to three steps back and firmly plant your feet with a roughly shoulder-width stance and a slight 15-degree foot flare. You want to point your elbows slightly outside your shoulders, and this will be your starting position. Although I wouldn't normally recommend a thumbless, so-called suicide grip for anyone new to the movement, as you get more comfortable with it, I think the thumbless grip can be used here as long as your wrists are stacked, meaning from the side position the bar should be resting above the wrist joint, not behind the wrist joint near the fingers. You want to externally rotate your shoulders, pushing the elbows slightly out at about a 45-degree angle. You don't want them flared too much out to the sides, which can cause shoulder pain, and you don't want them straight in front of the shoulders, which will limit your strength potential. With the bar resting on your upper chest or collarbone"),
#  Document(metadata={'video_id': '_RlRDWO2jfg', 'title': 'Build Bigger Shoulders With Perfect Training Technique (The Overhead Press)', 'author': 'Jeff Nippard', 'difficulty': 'intermediate', 'exercise_type': 'overhead_press'}, page_content="the sides, which can cause shoulder pain, and you don't want them straight in front of the shoulders, which will limit your strength potential. With the bar resting on your upper chest or collarbone area, you want to flex your glutes to ensure that your spine is kept neutral and take a deep breath into your gut, pressing the air out against your belt if you have one, which is going to increase intra-abdominal pressure and torso rigidity. As you press, while holding your breath, press the bar straight up, not up and forward or up and backward. When viewed from the side, the bar should be traveling up in a pretty much straight line. In order to keep the bar from hitting your chin, you'll have to slightly tilt your head back as you initiate the press, then as you clear your face, push your head forward back to a neutral position. Throughout the concentric, you want to keep your knees, hips, and shoulder blades motionless. The common error here is to shrug your shoulders up to initiate"),
#  Document(metadata={'video_id': '_RlRDWO2jfg', 'title': 'Build Bigger Shoulders With Perfect Training Technique (The Overhead Press)', 'author': 'Jeff Nippard', 'difficulty': 'intermediate', 'exercise_type': 'overhead_press'}, page_content='head forward back to a neutral position. Throughout the concentric, you want to keep your knees, hips, and shoulder blades motionless. The common error here is to shrug your shoulders up to initiate the concentric off the chest, and while this may make the movement easier in the short term, I think in the long term it really can weaken your bottom-end concentric pressing ability and end up limiting your true max strength potential. Press the bar all the way up until your elbows lock out with the bar overhead centered over the shoulder joint. At the end of the range of motion, there should be a pretty much straight line connecting the barbell, the shoulders, the hips, and the middle of the foot. This will keep everything in balance and prevent you from shifting your weight excessively forward onto your toes or backward onto your heels. Everything should be balanced directly over the middle of the foot. Start the eccentric by dropping your elbows down and to the side at a 45-degree'),
#  Document(metadata={'video_id': '_RlRDWO2jfg', 'title': 'Build Bigger Shoulders With Perfect Training Technique (The Overhead Press)', 'author': 'Jeff Nippard', 'difficulty': 'intermediate', 'exercise_type': 'overhead_press'}, page_content="forward onto your toes or backward onto your heels. Everything should be balanced directly over the middle of the foot. Start the eccentric by dropping your elbows down and to the side at a 45-degree angle, so not straight down in front of your delts. Allow the bar to come to a full and complete stop here while you take in another full breath of air and begin another rep. Of course, I think both the seated and the standing dumbbell shoulder press make for reasonable alternatives or additions here, since including isolateral movements can help prevent muscle imbalances and asymmetries. The seated variation will allow for the use of heavier loads; however, the standing variation will increase stabilization demands, meaning more core and side delt activation. Unlike with the barbell press, here you can just press the dumbbells straight up, with the dumbbells more out to the sides, since you don't need to worry about smashing your face on the way up. For the dumbbell variations, I prefer"),
#  Document(metadata={'video_id': '_RlRDWO2jfg', 'title': 'Build Bigger Shoulders With Perfect Training Technique (The Overhead Press)', 'author': 'Jeff Nippard', 'difficulty': 'intermediate', 'exercise_type': 'overhead_press'}, page_content="you can just press the dumbbells straight up, with the dumbbells more out to the sides, since you don't need to worry about smashing your face on the way up. For the dumbbell variations, I prefer slightly higher reps, usually in the 8 to 15 rep zone. I would say the most common error that I see here is just not using a full range of motion. Similar to the pull-up, many people will cut the range of motion short at the top and the bottom, not going to full lockout and also not touching the chest at the bottom. Keeping your range of motion consistent will ensure you're actually gaining strength through progressive overload, not progressive decreases in range of motion. Although not inherently problematic or injurious, I am going to consider doing touch-and-go reps as another error here, since they're going to create more inconsistent reps and often lead to bouncy reps with lots of momentum and reliance on that stretch reflex at the bottom. If any of this gets too excessive, I think it"),
#  Document(metadata={'video_id': '_RlRDWO2jfg', 'title': 'Build Bigger Shoulders With Perfect Training Technique (The Overhead Press)', 'author': 'Jeff Nippard', 'difficulty': 'intermediate', 'exercise_type': 'overhead_press'}, page_content="they're going to create more inconsistent reps and often lead to bouncy reps with lots of momentum and reliance on that stretch reflex at the bottom. If any of this gets too excessive, I think it really can hinder your true brute pressing strength required to get that bar moving from a dead stop. A third error that I see here all the time is not flexing the glutes. The goal of this exercise is to press the bar as vertically as you comfortably can, and keeping your glutes relaxed will usually result in the hips being back behind the bar, which reduces stability and more often than not results in the bar being pressed forward rather than straight up. This is a bad habit and can put a lot of strain on your lower back and create more inconsistency in both your bar path and form in general. Okay, so that's all that I have for the overhead press, guys. Before you click out of this one, I've got a quick rundown of what I have planned for the next few Technique Tuesday episodes. You guys may"),
#  Document(metadata={'video_id': '_RlRDWO2jfg', 'title': 'Build Bigger Shoulders With Perfect Training Technique (The Overhead Press)', 'author': 'Jeff Nippard', 'difficulty': 'intermediate', 'exercise_type': 'overhead_press'}, page_content="so that's all that I have for the overhead press, guys. Before you click out of this one, I've got a quick rundown of what I have planned for the next few Technique Tuesday episodes. You guys may have noticed that I've been skipping leg day so far in the series. For the next three episodes, we're going to hit three different lower body exercises, starting with the squat next week. I should say here that there is no underlying method or meaning to the order in which I'm covering these exercises. I'm obviously trying to focus on exercises that I think are smart to include in your program, but I'm trying to space out the more time-consuming and longer videos, like the squat, bench press, and deadlift, so I don't burn out too quickly on production from the beginning. Anyway, all those videos are coming, and I have the whole series mapped out until about mid-June as of now. For the release of the first shoulder-related video here, I'm going to be offering my men and women's shoulder"),
#  Document(metadata={'video_id': '_RlRDWO2jfg', 'title': 'Build Bigger Shoulders With Perfect Training Technique (The Overhead Press)', 'author': 'Jeff Nippard', 'difficulty': 'intermediate', 'exercise_type': 'overhead_press'}, page_content="are coming, and I have the whole series mapped out until about mid-June as of now. For the release of the first shoulder-related video here, I'm going to be offering my men and women's shoulder hypertrophy training program or training manual at 50% off. For this week, you can get it for $9.99. You can find these at the discounted rate for the next week on my website, JeffNippert.com, or by clicking the first link in the description. Guys, don't forget to leave me a like on the video if you enjoyed it, don't forget to subscribe so that you don't miss future Technique Tuesday episodes, and I'll see you guys all here next Tuesday for the squat.")]

# %% [markdown]
# ## Jeff Nippard: Bench Press transcript

# %%
jeff_bench = "/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/data/processed/cleaned_nippard_bench_dict"
jeff_bench_chunked = split_text_add_metadata(jeff_bench)
jeff_bench_chunked
# Out:
# [Document(metadata={'video_id': 'vcBig73ojpE', 'title': 'How To Get A Huge Bench Press with Perfect Technique', 'author': 'Jeff Nippard', 'difficulty': 'intermediate', 'exercise_type': 'bench_press'}, page_content="Welcome, everyone, to the first episode of Technique Tuesday, where every week we're going to take an in-depth look at the lost art and science of training technique. Just as a quick general outline, for the most part, we will break each exercise into four sections. We will look at the muscles we'll be targeting, how to set up for the exercise, the execution of the movement, and common errors that I see many people make. So without further ado, let's jump right into it with the bench press exercise."),
#  Document(metadata={'video_id': 'vcBig73ojpE', 'title': 'How To Get A Huge Bench Press with Perfect Technique', 'author': 'Jeff Nippard', 'difficulty': 'intermediate', 'exercise_type': 'bench_press'}, page_content="The muscles we'll be targeting here, in order of involvement, are the pec major, both the sternal (mid and lower) and clavicular (upper) heads, the triceps brachii, the anterior (front) deltoid, and, to a lesser extent, the lats. They'll only be active when the shoulder is behind the torso, at the very bottom of the press. The primary actions being trained are horizontal shoulder adduction, carried out mainly by the pecs and anterior deltoids, some degree of shoulder flexion by the upper pecs and front delt, and elbow extension, primarily handled by the triceps.\n\nBefore we get into the full setup, it's important to emphasize that you should only compare your bench strength to your starting place and not to anyone else's. Many extraneous factors can contribute to performance on this lift, like arm length, rib cage size, muscle origins and insertions, lumbar spine mobility, and the size and strength of your upper back for creating a stable base of support."),
#  Document(metadata={'video_id': 'vcBig73ojpE', 'title': 'How To Get A Huge Bench Press with Perfect Technique', 'author': 'Jeff Nippard', 'difficulty': 'intermediate', 'exercise_type': 'bench_press'}, page_content="The setup for the bench press is extremely important, and you may want to play this back a couple of times. I'll go through a strength-focused powerlifting-style bench press, which is a great mass builder for anyone aiming to build size. However, I'll explain slight modifications you can make if you have purely bodybuilding interests."),
#  Document(metadata={'video_id': 'vcBig73ojpE', 'title': 'How To Get A Huge Bench Press with Perfect Technique', 'author': 'Jeff Nippard', 'difficulty': 'intermediate', 'exercise_type': 'bench_press'}, page_content="Here we go. First, double-check that you have the right weight on both sides, that the bar is centered in the rack, and that you have a spotter handy if you're training at high efforts. Lie flat on the bench with your head back behind the bar. With your feet up on the bench, squeeze your shoulder blades together, keeping them in this retracted position throughout the setup and execution of the lift. Setup your arch by lifting your arms up and grabbing the bar with a shoulder-width grip, or you can reach back and push against the bench's uprights. I prefer just grabbing the bar. Lift your hips high, pulling your shoulder blades to your butt. This helps force you into scapular depression and pushes your upper body forward, keeping your feet in place. You can go up onto your toes if you find you can get more arch that way."),
#  Document(metadata={'video_id': 'vcBig73ojpE', 'title': 'How To Get A Huge Bench Press with Perfect Technique', 'author': 'Jeff Nippard', 'difficulty': 'intermediate', 'exercise_type': 'bench_press'}, page_content="Now, your back should be planted on the bench, with your eyes directly under the barbell. Position your lower body for leg drive by lowering one foot at a time, positioning your feet as far back as you comfortably can, and keeping your legs close to the bench when viewed from the front. If using regulation technique, your heels should be planted on the ground, so you may need to externally rotate your feet or point your toes out. Make sure your hips are down so your butt touches the bench. Take your grip at this point. I widen my grip, which is on the wider side, as I'm stronger with a wider grip."),
#  Document(metadata={'video_id': 'vcBig73ojpE', 'title': 'How To Get A Huge Bench Press with Perfect Technique', 'author': 'Jeff Nippard', 'difficulty': 'intermediate', 'exercise_type': 'bench_press'}, page_content="Research has found that wider grips will target the sternal head of the pecs and anterior delts more, while a closer grip will target the triceps and clavicular (upper) chest more. Using a variety of grip widths and experimenting to find what works best for you makes sense. However, an important factor in determining grip width is whether your joints are stacked from the rear position, meaning the wrist should be roughly positioned over the elbows. It's worth noting advanced powerlifters may not always keep the joints perfectly stacked. A 2007 study suggests a max width of 1.5 times the acromial distance (roughly 1.5 times shoulder-width) can reduce injury risk without seriously compromising maximal strength."),
#  Document(metadata={'video_id': 'vcBig73ojpE', 'title': 'How To Get A Huge Bench Press with Perfect Technique', 'author': 'Jeff Nippard', 'difficulty': 'intermediate', 'exercise_type': 'bench_press'}, page_content='Another important point regarding grip is ensuring your wrist joints are stacked. From the side view, your wrist should be directly below your knuckles, avoiding excessive hyperextension. You can correct this by thinking about punching the ceiling as a cue. Before the lift-off, do one last check to make sure your shoulder blades are retracted and depressed by cranking your elbows forward, which I think of as screwing my back into position.'),
#  Document(metadata={'video_id': 'vcBig73ojpE', 'title': 'How To Get A Huge Bench Press with Perfect Technique', 'author': 'Jeff Nippard', 'difficulty': 'intermediate', 'exercise_type': 'bench_press'}, page_content="For those interested in bodybuilding only, the general setup can still apply. You won't need as extreme of an arch, and may want to take a slightly more narrow grip to increase the range of motion. Because your arch will be smaller, your feet can be a bit further forward, but still, for shoulder health and stability, keep your shoulder blades retracted and maintain some arch in your lumbar spine. People tend to exaggerate the difference in range of motion between a big arch and a small arch. It's worth noting that the distance traveled by the bar isn't necessarily the same as joint range of motion. For example, compare the joint angles in these two bench press styles. The position of the humerus relative to the torso at the end of the range of motion is similar despite the bar traveling further in the flat back press. You should work on building your arch and not worry too much about limiting your range of motion when using it."),
#  Document(metadata={'video_id': 'vcBig73ojpE', 'title': 'How To Get A Huge Bench Press with Perfect Technique', 'author': 'Jeff Nippard', 'difficulty': 'intermediate', 'exercise_type': 'bench_press'}, page_content="We've got the bench press setup down; now it's time to execute the set. We'll break the execution into four phases: unrack, brace, descend, and press. First, unrack the bar with your spotter's help, lifting out, not up, or, if unracking by yourself, keep your butt elevated for the liftoff component, then drop your hips once you've unracked. I prefer having a spotter near a maximal effort to help with the liftoff. Ensure you have four main points of contact: your head, upper back, glutes, and feet should all be planted. In position, take a deep breath into your gut, pressing the air out against your belt if you have one. You can cue yourself to puff your chest out to expand the rib cage as much as possible. Grip the bar as hard as you can. You can optionally use the cue to bend the bar or rip it in half, activating your upper back muscles to maintain tightness. During the descent, drop your elbows at a 45-degree angle relative to your torso when viewed from the top. There's unanimous"),
#  Document(metadata={'video_id': 'vcBig73ojpE', 'title': 'How To Get A Huge Bench Press with Perfect Technique', 'author': 'Jeff Nippard', 'difficulty': 'intermediate', 'exercise_type': 'bench_press'}, page_content="rip it in half, activating your upper back muscles to maintain tightness. During the descent, drop your elbows at a 45-degree angle relative to your torso when viewed from the top. There's unanimous agreement on this from the best powerlifting coaches. When viewed from the side, the elbows shouldn't be too far in front of the bar. Aim to keep the elbow stacked under the bar. The descending bar path should be down and slightly forward. Touch your chest just below nipple level, toward the bottom of your sternum, which should be the highest contact point on your chest. You can optionally pause on your chest for about a second until the bar becomes motionless, which is required for competitive powerlifting. For bodybuilding, simply tap your chest without a pause. Ensure the touch is well controlled and not bouncing the weight off your chest."),
#  Document(metadata={'video_id': 'vcBig73ojpE', 'title': 'How To Get A Huge Bench Press with Perfect Technique', 'author': 'Jeff Nippard', 'difficulty': 'intermediate', 'exercise_type': 'bench_press'}, page_content="After your optional pause, explode the bar off your chest, driving your heels into the floor. Think about pressing the bar back toward your face and off your chest, rather than just driving the bar straight up. Think about pushing the floor away from you with your feet to help initiate leg drive and enforce this back-and-up bar path. Don't press the bar too far back; it shouldn't hit the rack or cause you to lose control. Bring it back into balance over the shoulder joint, restoring the starting position. On the way up, you might encounter a sticking point if training at high efforts where the lift feels most difficult. It's likely where you'll fail the lift if going for a max effort set. Research shows it tends to be in the first 20 to 40% of the movement, about 3 to 4 inches off the chest. It'll be individual; typically, the more advanced you are, the lower the sticking point, and the newer you are, the more it'll be in the mid-range. To break through the sticking point, ensure"),
#  Document(metadata={'video_id': 'vcBig73ojpE', 'title': 'How To Get A Huge Bench Press with Perfect Technique', 'author': 'Jeff Nippard', 'difficulty': 'intermediate', 'exercise_type': 'bench_press'}, page_content="chest. It'll be individual; typically, the more advanced you are, the lower the sticking point, and the newer you are, the more it'll be in the mid-range. To break through the sticking point, ensure you're pressing the bar up and back, not just straight up. You can try flaring the elbows out a bit more to get your pecs to help the triceps. Think about lifting the bar off your chest with max speed to blast through the point where deceleration would normally happen. The simplest solution is likely you need stronger pecs and triceps."),
#  Document(metadata={'video_id': 'vcBig73ojpE', 'title': 'How To Get A Huge Bench Press with Perfect Technique', 'author': 'Jeff Nippard', 'difficulty': 'intermediate', 'exercise_type': 'bench_press'}, page_content="Once you're accelerating past the sticking point, you can opt to exhale, but you can hold your breath until you fully lock the lift out. As you near the end range of motion, the bar should complete the arc back toward the starting position over the nipples. Repeat the process, starting with bracing, descending, and pressing again for however many reps your program calls for."),
#  Document(metadata={'video_id': 'vcBig73ojpE', 'title': 'How To Get A Huge Bench Press with Perfect Technique', 'author': 'Jeff Nippard', 'difficulty': 'intermediate', 'exercise_type': 'bench_press'}, page_content="Three common errors I see all the time with the bench press are first, over-tucking or under-tucking the elbows. The cue to tuck your elbows originated in equipped powerlifting, but without a bench shirt, it may not be helpful for you. It's just as common to see people not tucking enough, flaring their elbows out parallel with the bar. This is also not ideal; it puts your shoulder at an increased risk of injury and makes the bar path less efficient since it's forced to go straight up and down. Most won't be as strong benching with flared elbows. A slight tuck is good. As you get to the sticking point, more of a flair might help you finish the lift. If you have difficulty figuring out how you're using your elbows, I'd recommend slow eccentric presses with lighter weights to be mindful of where your elbows are and where they're going."),
#  Document(metadata={'video_id': 'vcBig73ojpE', 'title': 'How To Get A Huge Bench Press with Perfect Technique', 'author': 'Jeff Nippard', 'difficulty': 'intermediate', 'exercise_type': 'bench_press'}, page_content="The second common error is benching with a completely flat back. You may not need as extreme of an arch as a competitive powerlifter, but maintaining some arch confers at least three major benefits: first, the lumbar and thoracic vertebrae and intervertebral discs are safer in the lordotic or arched position; the more decline pushing angle is safer for the shoulder joint; and you'll likely be stronger in this position, meaning more total load on the active muscle groups.\n\nThe third error is a lack of leg drive. If your feet are positioned wherever, just out in front of you on the bench rather than tucked behind you, you're not maximizing your strength potential. Figuring out how to use your legs in the bench press may take time, but mastering it is important. I've linked a few good articles in the description."),
#  Document(metadata={'video_id': 'vcBig73ojpE', 'title': 'How To Get A Huge Bench Press with Perfect Technique', 'author': 'Jeff Nippard', 'difficulty': 'intermediate', 'exercise_type': 'bench_press'}, page_content="Alongside this video, I'll be releasing my bench press specialization program. Like most of my programs, it's more of a bench press training manual, which covers way more detail than I could touch on here. It includes an eight-week training program for intermediate to advanced level lifters aiming to increase bench press strength. It's more than just a bench program; it's an upper-lower training split five days a week, focusing on developing bench strength as that exercise is hit three times per week using daily undulating periodization. \n\nThe program is $29.99, but with the discount code TECHNIQUETUESDAY, you can save $10, bringing it down to $19.99 for the first week of launch. Learn more on my website at jeffnippard.com or click the first link in the description. I hope you enjoyed the video. I've been excited about this series, and we're finally underway. Please leave a like if you enjoyed the video. Don't forget to subscribe if you're new, and I'll see you all next Tuesday.")]

# %% [markdown]
# ## Jeff Nippard: Squat transcript

# %%
jeff_squat = "/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/data/processed/cleaned_nippard_squat_dict"
jeff_squat_chunked = split_text_add_metadata(jeff_squat)
jeff_bench_chunked
# Out:
# [Document(metadata={'video_id': 'vcBig73ojpE', 'title': 'How To Get A Huge Bench Press with Perfect Technique', 'author': 'Jeff Nippard', 'difficulty': 'intermediate', 'exercise_type': 'bench_press'}, page_content="Welcome, everyone, to the first episode of Technique Tuesday, where every week we're going to take an in-depth look at the lost art and science of training technique. Just as a quick general outline, for the most part, we will break each exercise into four sections. We will look at the muscles we'll be targeting, how to set up for the exercise, the execution of the movement, and common errors that I see many people make. So without further ado, let's jump right into it with the bench press exercise."),
#  Document(metadata={'video_id': 'vcBig73ojpE', 'title': 'How To Get A Huge Bench Press with Perfect Technique', 'author': 'Jeff Nippard', 'difficulty': 'intermediate', 'exercise_type': 'bench_press'}, page_content="The muscles we'll be targeting here, in order of involvement, are the pec major, both the sternal (mid and lower) and clavicular (upper) heads, the triceps brachii, the anterior (front) deltoid, and, to a lesser extent, the lats. They'll only be active when the shoulder is behind the torso, at the very bottom of the press. The primary actions being trained are horizontal shoulder adduction, carried out mainly by the pecs and anterior deltoids, some degree of shoulder flexion by the upper pecs and front delt, and elbow extension, primarily handled by the triceps.\n\nBefore we get into the full setup, it's important to emphasize that you should only compare your bench strength to your starting place and not to anyone else's. Many extraneous factors can contribute to performance on this lift, like arm length, rib cage size, muscle origins and insertions, lumbar spine mobility, and the size and strength of your upper back for creating a stable base of support."),
#  Document(metadata={'video_id': 'vcBig73ojpE', 'title': 'How To Get A Huge Bench Press with Perfect Technique', 'author': 'Jeff Nippard', 'difficulty': 'intermediate', 'exercise_type': 'bench_press'}, page_content="The setup for the bench press is extremely important, and you may want to play this back a couple of times. I'll go through a strength-focused powerlifting-style bench press, which is a great mass builder for anyone aiming to build size. However, I'll explain slight modifications you can make if you have purely bodybuilding interests."),
#  Document(metadata={'video_id': 'vcBig73ojpE', 'title': 'How To Get A Huge Bench Press with Perfect Technique', 'author': 'Jeff Nippard', 'difficulty': 'intermediate', 'exercise_type': 'bench_press'}, page_content="Here we go. First, double-check that you have the right weight on both sides, that the bar is centered in the rack, and that you have a spotter handy if you're training at high efforts. Lie flat on the bench with your head back behind the bar. With your feet up on the bench, squeeze your shoulder blades together, keeping them in this retracted position throughout the setup and execution of the lift. Setup your arch by lifting your arms up and grabbing the bar with a shoulder-width grip, or you can reach back and push against the bench's uprights. I prefer just grabbing the bar. Lift your hips high, pulling your shoulder blades to your butt. This helps force you into scapular depression and pushes your upper body forward, keeping your feet in place. You can go up onto your toes if you find you can get more arch that way."),
#  Document(metadata={'video_id': 'vcBig73ojpE', 'title': 'How To Get A Huge Bench Press with Perfect Technique', 'author': 'Jeff Nippard', 'difficulty': 'intermediate', 'exercise_type': 'bench_press'}, page_content="Now, your back should be planted on the bench, with your eyes directly under the barbell. Position your lower body for leg drive by lowering one foot at a time, positioning your feet as far back as you comfortably can, and keeping your legs close to the bench when viewed from the front. If using regulation technique, your heels should be planted on the ground, so you may need to externally rotate your feet or point your toes out. Make sure your hips are down so your butt touches the bench. Take your grip at this point. I widen my grip, which is on the wider side, as I'm stronger with a wider grip."),
#  Document(metadata={'video_id': 'vcBig73ojpE', 'title': 'How To Get A Huge Bench Press with Perfect Technique', 'author': 'Jeff Nippard', 'difficulty': 'intermediate', 'exercise_type': 'bench_press'}, page_content="Research has found that wider grips will target the sternal head of the pecs and anterior delts more, while a closer grip will target the triceps and clavicular (upper) chest more. Using a variety of grip widths and experimenting to find what works best for you makes sense. However, an important factor in determining grip width is whether your joints are stacked from the rear position, meaning the wrist should be roughly positioned over the elbows. It's worth noting advanced powerlifters may not always keep the joints perfectly stacked. A 2007 study suggests a max width of 1.5 times the acromial distance (roughly 1.5 times shoulder-width) can reduce injury risk without seriously compromising maximal strength."),
#  Document(metadata={'video_id': 'vcBig73ojpE', 'title': 'How To Get A Huge Bench Press with Perfect Technique', 'author': 'Jeff Nippard', 'difficulty': 'intermediate', 'exercise_type': 'bench_press'}, page_content='Another important point regarding grip is ensuring your wrist joints are stacked. From the side view, your wrist should be directly below your knuckles, avoiding excessive hyperextension. You can correct this by thinking about punching the ceiling as a cue. Before the lift-off, do one last check to make sure your shoulder blades are retracted and depressed by cranking your elbows forward, which I think of as screwing my back into position.'),
#  Document(metadata={'video_id': 'vcBig73ojpE', 'title': 'How To Get A Huge Bench Press with Perfect Technique', 'author': 'Jeff Nippard', 'difficulty': 'intermediate', 'exercise_type': 'bench_press'}, page_content="For those interested in bodybuilding only, the general setup can still apply. You won't need as extreme of an arch, and may want to take a slightly more narrow grip to increase the range of motion. Because your arch will be smaller, your feet can be a bit further forward, but still, for shoulder health and stability, keep your shoulder blades retracted and maintain some arch in your lumbar spine. People tend to exaggerate the difference in range of motion between a big arch and a small arch. It's worth noting that the distance traveled by the bar isn't necessarily the same as joint range of motion. For example, compare the joint angles in these two bench press styles. The position of the humerus relative to the torso at the end of the range of motion is similar despite the bar traveling further in the flat back press. You should work on building your arch and not worry too much about limiting your range of motion when using it."),
#  Document(metadata={'video_id': 'vcBig73ojpE', 'title': 'How To Get A Huge Bench Press with Perfect Technique', 'author': 'Jeff Nippard', 'difficulty': 'intermediate', 'exercise_type': 'bench_press'}, page_content="We've got the bench press setup down; now it's time to execute the set. We'll break the execution into four phases: unrack, brace, descend, and press. First, unrack the bar with your spotter's help, lifting out, not up, or, if unracking by yourself, keep your butt elevated for the liftoff component, then drop your hips once you've unracked. I prefer having a spotter near a maximal effort to help with the liftoff. Ensure you have four main points of contact: your head, upper back, glutes, and feet should all be planted. In position, take a deep breath into your gut, pressing the air out against your belt if you have one. You can cue yourself to puff your chest out to expand the rib cage as much as possible. Grip the bar as hard as you can. You can optionally use the cue to bend the bar or rip it in half, activating your upper back muscles to maintain tightness. During the descent, drop your elbows at a 45-degree angle relative to your torso when viewed from the top. There's unanimous"),
#  Document(metadata={'video_id': 'vcBig73ojpE', 'title': 'How To Get A Huge Bench Press with Perfect Technique', 'author': 'Jeff Nippard', 'difficulty': 'intermediate', 'exercise_type': 'bench_press'}, page_content="rip it in half, activating your upper back muscles to maintain tightness. During the descent, drop your elbows at a 45-degree angle relative to your torso when viewed from the top. There's unanimous agreement on this from the best powerlifting coaches. When viewed from the side, the elbows shouldn't be too far in front of the bar. Aim to keep the elbow stacked under the bar. The descending bar path should be down and slightly forward. Touch your chest just below nipple level, toward the bottom of your sternum, which should be the highest contact point on your chest. You can optionally pause on your chest for about a second until the bar becomes motionless, which is required for competitive powerlifting. For bodybuilding, simply tap your chest without a pause. Ensure the touch is well controlled and not bouncing the weight off your chest."),
#  Document(metadata={'video_id': 'vcBig73ojpE', 'title': 'How To Get A Huge Bench Press with Perfect Technique', 'author': 'Jeff Nippard', 'difficulty': 'intermediate', 'exercise_type': 'bench_press'}, page_content="After your optional pause, explode the bar off your chest, driving your heels into the floor. Think about pressing the bar back toward your face and off your chest, rather than just driving the bar straight up. Think about pushing the floor away from you with your feet to help initiate leg drive and enforce this back-and-up bar path. Don't press the bar too far back; it shouldn't hit the rack or cause you to lose control. Bring it back into balance over the shoulder joint, restoring the starting position. On the way up, you might encounter a sticking point if training at high efforts where the lift feels most difficult. It's likely where you'll fail the lift if going for a max effort set. Research shows it tends to be in the first 20 to 40% of the movement, about 3 to 4 inches off the chest. It'll be individual; typically, the more advanced you are, the lower the sticking point, and the newer you are, the more it'll be in the mid-range. To break through the sticking point, ensure"),
#  Document(metadata={'video_id': 'vcBig73ojpE', 'title': 'How To Get A Huge Bench Press with Perfect Technique', 'author': 'Jeff Nippard', 'difficulty': 'intermediate', 'exercise_type': 'bench_press'}, page_content="chest. It'll be individual; typically, the more advanced you are, the lower the sticking point, and the newer you are, the more it'll be in the mid-range. To break through the sticking point, ensure you're pressing the bar up and back, not just straight up. You can try flaring the elbows out a bit more to get your pecs to help the triceps. Think about lifting the bar off your chest with max speed to blast through the point where deceleration would normally happen. The simplest solution is likely you need stronger pecs and triceps."),
#  Document(metadata={'video_id': 'vcBig73ojpE', 'title': 'How To Get A Huge Bench Press with Perfect Technique', 'author': 'Jeff Nippard', 'difficulty': 'intermediate', 'exercise_type': 'bench_press'}, page_content="Once you're accelerating past the sticking point, you can opt to exhale, but you can hold your breath until you fully lock the lift out. As you near the end range of motion, the bar should complete the arc back toward the starting position over the nipples. Repeat the process, starting with bracing, descending, and pressing again for however many reps your program calls for."),
#  Document(metadata={'video_id': 'vcBig73ojpE', 'title': 'How To Get A Huge Bench Press with Perfect Technique', 'author': 'Jeff Nippard', 'difficulty': 'intermediate', 'exercise_type': 'bench_press'}, page_content="Three common errors I see all the time with the bench press are first, over-tucking or under-tucking the elbows. The cue to tuck your elbows originated in equipped powerlifting, but without a bench shirt, it may not be helpful for you. It's just as common to see people not tucking enough, flaring their elbows out parallel with the bar. This is also not ideal; it puts your shoulder at an increased risk of injury and makes the bar path less efficient since it's forced to go straight up and down. Most won't be as strong benching with flared elbows. A slight tuck is good. As you get to the sticking point, more of a flair might help you finish the lift. If you have difficulty figuring out how you're using your elbows, I'd recommend slow eccentric presses with lighter weights to be mindful of where your elbows are and where they're going."),
#  Document(metadata={'video_id': 'vcBig73ojpE', 'title': 'How To Get A Huge Bench Press with Perfect Technique', 'author': 'Jeff Nippard', 'difficulty': 'intermediate', 'exercise_type': 'bench_press'}, page_content="The second common error is benching with a completely flat back. You may not need as extreme of an arch as a competitive powerlifter, but maintaining some arch confers at least three major benefits: first, the lumbar and thoracic vertebrae and intervertebral discs are safer in the lordotic or arched position; the more decline pushing angle is safer for the shoulder joint; and you'll likely be stronger in this position, meaning more total load on the active muscle groups.\n\nThe third error is a lack of leg drive. If your feet are positioned wherever, just out in front of you on the bench rather than tucked behind you, you're not maximizing your strength potential. Figuring out how to use your legs in the bench press may take time, but mastering it is important. I've linked a few good articles in the description."),
#  Document(metadata={'video_id': 'vcBig73ojpE', 'title': 'How To Get A Huge Bench Press with Perfect Technique', 'author': 'Jeff Nippard', 'difficulty': 'intermediate', 'exercise_type': 'bench_press'}, page_content="Alongside this video, I'll be releasing my bench press specialization program. Like most of my programs, it's more of a bench press training manual, which covers way more detail than I could touch on here. It includes an eight-week training program for intermediate to advanced level lifters aiming to increase bench press strength. It's more than just a bench program; it's an upper-lower training split five days a week, focusing on developing bench strength as that exercise is hit three times per week using daily undulating periodization. \n\nThe program is $29.99, but with the discount code TECHNIQUETUESDAY, you can save $10, bringing it down to $19.99 for the first week of launch. Learn more on my website at jeffnippard.com or click the first link in the description. I hope you enjoyed the video. I've been excited about this series, and we're finally underway. Please leave a like if you enjoyed the video. Don't forget to subscribe if you're new, and I'll see you all next Tuesday.")]

# %% [markdown]
# # Learning to Bench Press | The Starting Strength Method transcript

# %%
strength_bench = "/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/data/processed/cleaned_starting_strength_bench_dict"
strength_bench_chunked = split_text_add_metadata(strength_bench)
strength_bench_chunked
# Out:
# [Document(metadata={'video_id': 'rxD321l2svE', 'title': 'Learning to Bench Press | The Starting Strength Method', 'author': 'Mark Rippetoe', 'difficulty': 'advanced', 'exercise_type': 'bench_Press'}, page_content="When you're learning how to bench press, it might be prudent to use a spotter if one is available. However, if you're working inside a correctly set up power rack, a spotter is not absolutely necessary. Start with an empty bar. Lie down on the bench with your eyes looking straight up. In this position, you should be far enough down from the bar—meaning toward the foot end of the bench—that when you look up, your eyes are focused on the downside of the bar. Your feet should be flat on the ground with your shins approximately vertical. Your upper back should be flat against the bench with your lower back in an anatomically normal arched position. Take an overhand grip on the bar; your grip should be somewhere between 22 and 24 inches measured between the index fingers. This grip width will result in a vertical forearm for most people when the bar is touching the chest at the bottom. The bar should rest on the heel of your palm, not on the fingers, and directly over the bones of the"),
#  Document(metadata={'video_id': 'rxD321l2svE', 'title': 'Learning to Bench Press | The Starting Strength Method', 'author': 'Mark Rippetoe', 'difficulty': 'advanced', 'exercise_type': 'bench_Press'}, page_content='result in a vertical forearm for most people when the bar is touching the chest at the bottom. The bar should rest on the heel of your palm, not on the fingers, and directly over the bones of the forearm. Just like the press, this grip is best accomplished by pronating your hands with a slight internal rotation of your arms. You are now ready to take the bar out of the rack. Look directly up at the ceiling and push up on the bar, locking out your elbows. Move the bar out to a position directly over the line of your shoulder joints. This is the place where the bar is in balance at lockout. Note carefully the position of the bar against the ceiling; this picture is your reference for the path the bar will take as you move it down and up. You will lower the bar to your chest, touch the chest, and then drive the bar right back to the exact position you are looking at on the ceiling overhead. Stare at the place on the ceiling where the bar is to go; do not watch the bar as it moves. With'),
#  Document(metadata={'video_id': 'rxD321l2svE', 'title': 'Learning to Bench Press | The Starting Strength Method', 'author': 'Mark Rippetoe', 'difficulty': 'advanced', 'exercise_type': 'bench_Press'}, page_content="and then drive the bar right back to the exact position you are looking at on the ceiling overhead. Stare at the place on the ceiling where the bar is to go; do not watch the bar as it moves. With the bar locked out over the shoulders, have your spotter touch your chest a few inches below the bar's vertical position, at about the middle of your sternum. This tactile cue will quite effectively identify the point on your chest to touch the bar. If there is no spotter and you're benching alone inside a rack, unlock your elbows and then allow them to drop towards your feet a little on the way down. If you do this correctly, the net effect will be the same as the spotter's touch. The bar will contact your sternum a few inches below your clavicles and therefore below your shoulder joints. Look at the ceiling, unlock your elbows, lower the bar to your chest, touch without stopping, and then drive the bar back at the point on the ceiling your eyes have trapped. Try it for a set of five reps."),
#  Document(metadata={'video_id': 'rxD321l2svE', 'title': 'Learning to Bench Press | The Starting Strength Method', 'author': 'Mark Rippetoe', 'difficulty': 'advanced', 'exercise_type': 'bench_Press'}, page_content="at the ceiling, unlock your elbows, lower the bar to your chest, touch without stopping, and then drive the bar back at the point on the ceiling your eyes have trapped. Try it for a set of five reps. You'll immediately notice that if your eyes don't move from their fixed position, the bar will go to the same place every rep. Do another set of five with the bar, reinforcing your eye position, and then rack the bar. This is done with locked elbows after the last rep is finished. Should you have a spotter, this movement back to the rack should be covered. Now that we've covered the basic movement pattern for the bench press, we can maximize the efficiency of the lift by improving the position of the upper back, legs, and feet. The upper back needs to be planted firmly against the bench and used as a platform to drive against while the arms drive the bar up. When this is done correctly, the shoulder blades will be adducted or pinched together. Sit on the bench in the same position you"),
#  Document(metadata={'video_id': 'rxD321l2svE', 'title': 'Learning to Bench Press | The Starting Strength Method', 'author': 'Mark Rippetoe', 'difficulty': 'advanced', 'exercise_type': 'bench_Press'}, page_content='used as a platform to drive against while the arms drive the bar up. When this is done correctly, the shoulder blades will be adducted or pinched together. Sit on the bench in the same position you assumed before lying down to take the bar. Imagine a hand touching you right between the shoulder blades and imagine pinching the hand between your shoulder blades. This pinching will also cause you to raise your chest, further contributing to a good position. Now lie down, take the bar out, and assume this same position, making sure your shoulder blades are pinched together and your chest is up high. Your goal is to be able to do all your reps without losing this set position against the bench. Used correctly, the legs drive against the floor during the bench press, transferring force horizontally along the bench through the hips into the arched back to reinforce the arch and keep the chest in its high position. Remember that you cannot raise your butt up off of the bench at any time'),
#  Document(metadata={'video_id': 'rxD321l2svE', 'title': 'Learning to Bench Press | The Starting Strength Method', 'author': 'Mark Rippetoe', 'difficulty': 'advanced', 'exercise_type': 'bench_Press'}, page_content="along the bench through the hips into the arched back to reinforce the arch and keep the chest in its high position. Remember that you cannot raise your butt up off of the bench at any time during the lift. Your foot position should be set so that your shins are nearly vertical. This position allows for the efficient use of your legs in reinforcing the arch, but it doesn't predispose you to bridge your butt up off of the bench. The proper position for the feet is flat against the floor so that the heels can be used as the base of the drive up the legs. If you're up on your toes, you cannot use the force of knee extension nearly as efficiently as you can if your heels are planted. For the next sets of five reps, add a little weight until the bar speed begins to slow down and your form starts to change. Stay at that weight for two more sets of five, and this is the first work set.")]

# %% [markdown]
# # How To Bench Press: Layne Norton's Complete Guide transcript

# %%
bodybuilding_bench = "/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/data/processed/cleaned_bodybuilding_bench_dict"
bodybuilding_bench_chunked = split_text_add_metadata(bodybuilding_bench)
bodybuilding_bench_chunked
# Out:
# [Document(metadata={'video_id': 'esQi683XR44', 'title': "How To Bench Press: Layne Norton's Complete Guide", 'author': 'Layne Norton', 'difficulty': 'beginner', 'exercise_type': 'bench_press'}, page_content="Research is my passion. Muscle and strength are my pursuits. I'm the powerlifter, bodybuilder, scientist, and coach. I'm Layne Norton. I am a physique architect. The bench press is one of the most important upper body exercises. This makes it crucial for overall development and strength. A lot of people think about it as just a chest movement, but it incorporates the pectorals, the triceps, the shoulders, and even the back when done correctly. When it's done wrong, the results can be disastrous. Seven years ago, I tore my right pectoral bench pressing incorrectly. But over time, I learned to incorporate more muscle groups and focus on the movement itself. Not only did it become more safe, but my results were better. In this video, I'm going to teach you things I learned from top technique experts like Ben Escrow, Dr. Mike Zourdos, and Matt Gary to make my bench press more effective, safe, and fun."),
#  Document(metadata={'video_id': 'esQi683XR44', 'title': "How To Bench Press: Layne Norton's Complete Guide", 'author': 'Layne Norton', 'difficulty': 'beginner', 'exercise_type': 'bench_press'}, page_content="Before we actually get into talking about the nuts and bolts, I want to talk about something a lot of people don't really think about—that's equipment. Now, you don't need any equipment other than yourself to bench press, but there are certain things that can make your bench press more effective and safe. Not many people give much thought to footwear on a bench press, but your feet are what connect you to the ground and form your base. Now, footwear is a little bit of personal preference, but you want something with a lot of grip. Personally, I like to use squat shoes. They have an elevated heel, which helps me get my foot flat on the floor and connect with it better. They also have really good grip on the bottom, and that helps keep my feet from sliding. But many people also use wrestling shoes and shoes like Chuck Taylors."),
#  Document(metadata={'video_id': 'esQi683XR44', 'title': "How To Bench Press: Layne Norton's Complete Guide", 'author': 'Layne Norton', 'difficulty': 'beginner', 'exercise_type': 'bench_press'}, page_content="Another piece that really isn't equipment but I find to be very useful is chalk. By putting chalk on my back, it helps me stick to the bench better and form a more stable base to press from. The easiest way to apply chalk is to use a partner or lifting buddy. Have them chalk your back where your back contacts the bench. The most important piece of equipment I use on the bench press is wrist straps. If you're going to create the maximum amount of force, you want to be able to keep your wrist in a straight line. Wrist straps give joint support, helping you keep your wrist in a straight line. I recommend a good pair of powerlifting wrist straps anywhere from 12 to 36 inches, depending on what you prefer. Many people make the mistake of wrapping their wrists too low. You want the wrap to actually cover the joint. In fact, you want to wrap a little bit above and a little bit below the joint. This is why I prefer a bit longer wrist wrap of eighteen to twenty-four inches. This ensures I can"),
#  Document(metadata={'video_id': 'esQi683XR44', 'title': "How To Bench Press: Layne Norton's Complete Guide", 'author': 'Layne Norton', 'difficulty': 'beginner', 'exercise_type': 'bench_press'}, page_content='cover the joint. In fact, you want to wrap a little bit above and a little bit below the joint. This is why I prefer a bit longer wrist wrap of eighteen to twenty-four inches. This ensures I can get enough revolutions to cover both above and below the wrist joint. Tightness is a little bit of a matter of personal preference. I say get them as tight as you can while not causing pain.'),
#  Document(metadata={'video_id': 'esQi683XR44', 'title': "How To Bench Press: Layne Norton's Complete Guide", 'author': 'Layne Norton', 'difficulty': 'beginner', 'exercise_type': 'bench_press'}, page_content="Now that we've covered equipment, let's talk about what actually makes the components of a good bench press. The first thing I want to talk about is foot placement. While not as crucial as on squat or deadlift, it still is important on the bench press. It forms your connection to the ground and your base. I prefer to keep a flat foot on the ground. This ensures I get the best connection possible. I also like to keep my back tight and arched. To do that, I like to keep my feet back as far as I can while still keeping them flat. For everyone, this is going to be a different position, but you want to put them back, but not so far back that you can't keep them flat on the floor."),
#  Document(metadata={'video_id': 'esQi683XR44', 'title': "How To Bench Press: Layne Norton's Complete Guide", 'author': 'Layne Norton', 'difficulty': 'beginner', 'exercise_type': 'bench_press'}, page_content="The next thing I want to talk about is back position. As you lie down on the bench, you want to position your back in the appropriate position. For everyone, this may be a little bit different, but essentially, what you want is to have your back in a position where you're not so far away from the bar that it becomes difficult to unrack, but you're not so far under it that you're likely to hit the pegs when you're pressing. I prefer to put the bar right around forehead height, and this will put my back connection with the bench just below where the bar sits on the rack."),
#  Document(metadata={'video_id': 'esQi683XR44', 'title': "How To Bench Press: Layne Norton's Complete Guide", 'author': 'Layne Norton', 'difficulty': 'beginner', 'exercise_type': 'bench_press'}, page_content="So now that we're in the proper position, I want to talk about back arch. Now, this tends to be a little bit of a controversial topic, especially amongst bodybuilders. Many bodybuilders don't think they should arch; they think that an arch is just a powerlifting move. But arching your lower back will help keep your spine neutral and protect it while you're pressing. It'll also ensure your overall back stays tighter. Now, if you're not concerned about powerlifting, maybe you don't need to arch as much as powerlifters, but you should still keep a slight arch in your lower back. If you're a powerlifter, then you want to arch as much as you possibly can to minimize the distance the bar has to travel."),
#  Document(metadata={'video_id': 'esQi683XR44', 'title': "How To Bench Press: Layne Norton's Complete Guide", 'author': 'Layne Norton', 'difficulty': 'beginner', 'exercise_type': 'bench_press'}, page_content="The next thing I want to talk about is gripping the bar. You want to grab it tightly and with authority. It's going to activate your central nervous system and get you ready and cue you to stay tight. You want to put the bar as far down in your hand as you possibly can. If you hold the bar out in your fingers, it is more likely to cause your wrist to roll back. This means you are no longer pressing with optimal force. A straight wrist will be the most optimal way to press, so you want to hold the bar as low in your hands as you can."),
#  Document(metadata={'video_id': 'esQi683XR44', 'title': "How To Bench Press: Layne Norton's Complete Guide", 'author': 'Layne Norton', 'difficulty': 'beginner', 'exercise_type': 'bench_press'}, page_content="Grip width is going to be very individual, depending on your arm length. People with longer arms will probably need to grip wider. People with shorter arms can grip more narrow, but I don't like exaggerated grips in either direction. Most people are going to be around the rings or just a few inches inside the rings. I also don't recommend a false or thumbless grip. While they may feel better, they are simply more dangerous. I've heard numerous stories of people dropping bars on their chest because they use the thumbless grip. Wrap your thumb around the bar and bench press more safely."),
#  Document(metadata={'video_id': 'esQi683XR44', 'title': "How To Bench Press: Layne Norton's Complete Guide", 'author': 'Layne Norton', 'difficulty': 'beginner', 'exercise_type': 'bench_press'}, page_content='The next thing I want to talk about is squeezing your shoulder blades together. Squeezing your shoulder blades together will allow you to stay tighter. It also protects the shoulders. What I mean by squeezing shoulder blades together is to think about if you had a grape between your shoulder blades—you want to squeeze so tight that you crush that grape. Just like on squat, we want to breathe to create the maximum amount of intra-abdominal pressure so we can brace more effectively and move more weight. Before you begin the movement, you want to take in a deep breath, unrack the bar, blow that breath out, and take in another new deep breath before you start your first rep. Then you want to hold it and blow out forcefully as you lock out the weight. This will enable you to use more weight more effectively.'),
#  Document(metadata={'video_id': 'esQi683XR44', 'title': "How To Bench Press: Layne Norton's Complete Guide", 'author': 'Layne Norton', 'difficulty': 'beginner', 'exercise_type': 'bench_press'}, page_content='One step that gets overlooked is unracking the bar. Just like on squat, we want to do this as efficiently as possible and not waste energy. The way I like to think about unracking the bar is not to lift the bar off the uprights, but I want to think about driving my back against the bench so hard that the bar just comes off. You want to take a deep breath, brace, drive your shoulder blades against the bench, and then slowly and in a controlled fashion pull the bar off the uprights.'),
#  Document(metadata={'video_id': 'esQi683XR44', 'title': "How To Bench Press: Layne Norton's Complete Guide", 'author': 'Layne Norton', 'difficulty': 'beginner', 'exercise_type': 'bench_press'}, page_content="Now we've gone through a proper setup on the bench press. Let's talk execution. After you've unracked the bar and you're ready to start your first rep, you want to take in a big breath and brace your abdominal wall, just like you would on squat or deadlift. Once you're braced, to initiate lowering the bar, think about trying to bend the bar into a U. This will enable the bar to lower naturally in a good position with your elbows tucked. By thinking about bending the bar, you're going to naturally engage your lats and tuck your elbows. We don't want to flare our elbows excessively on the bench press. Tucking your elbows ensures that you'll engage your lats and press in a more safe and efficient manner. Another cue that may work is to protect your armpits."),
#  Document(metadata={'video_id': 'esQi683XR44', 'title': "How To Bench Press: Layne Norton's Complete Guide", 'author': 'Layne Norton', 'difficulty': 'beginner', 'exercise_type': 'bench_press'}, page_content="Where you touch the bar on your body is very important and is going to be very different depending on how long your arms are and where you grip. One of the most important things for an efficient bench press is to keep your forearm at 90 degrees to the ground. If it moves in either direction, you're going to be losing energy transfer as you press up with the bar. Somebody who has long arms and grips narrow is going to have to touch very low on their body. If somebody has very short arms and grips very wide, they could touch very high and still keep the forearm at 90 degrees to the ground. But as we discussed, I don't recommend extreme grips in either direction. For most people, they're going to hit anywhere from their top ab to their nipple line."),
#  Document(metadata={'video_id': 'esQi683XR44', 'title': "How To Bench Press: Layne Norton's Complete Guide", 'author': 'Layne Norton', 'difficulty': 'beginner', 'exercise_type': 'bench_press'}, page_content="Once you've touched the bar to your chest, you want to initiate the upward movement by tightening your glutes and driving your legs into the ground. This may seem like a strange cue, but just like on squat and deadlift, using leg drive is going to enable you to use more weight and stay tighter. Now, on the bench press, because our feet are not directly under the bar, it's not as important as it is on squats and deadlifts. But we're still trying to get every little bit of efficiency that we can out of our movement. As you start to press up, you want to think about throwing the bar back as you start the lockout process. Remember, we're pressing the bar in an upside-down J path. Ideally, we'd have a completely straight bar path, but with most people on the bench press, that's not going to be possible. If they do, the bar ends up too far away from you as you lock out and creates extra torque on your shoulders."),
#  Document(metadata={'video_id': 'esQi683XR44', 'title': "How To Bench Press: Layne Norton's Complete Guide", 'author': 'Layne Norton', 'difficulty': 'beginner', 'exercise_type': 'bench_press'}, page_content="Now that we've talked about how to do a proper bench press, let's talk about some of the most common mistakes I see when people do the movement. Probably the most common mistake I see is people bouncing the bar off their chest. Not only is this dangerous because of the force you create on your sternum, but it's almost impossible to stay tight and controlled when you're bouncing the bar off your chest. And if you're bouncing it, are you really moving the weight? Another mistake is people don't breathe properly and brace properly. If you're not taking a big breath before you start and bracing your abdominal wall correctly, it's going to be less safe, and you're not going to be able to stay as tight and use as much weight."),
#  Document(metadata={'video_id': 'esQi683XR44', 'title': "How To Bench Press: Layne Norton's Complete Guide", 'author': 'Layne Norton', 'difficulty': 'beginner', 'exercise_type': 'bench_press'}, page_content="Another one of the most common mistakes I see is people flaring their elbows. Many people flare their elbows out because they believe this will lead to more chest recruitment. And even if it does, it's still not worth the danger. This was how I tore my pec seven years ago, by using too wide of a grip and flaring my elbows out. It also means you're not going to be able to keep your lats tight, and it's going to lead to less efficiency in the movement."),
#  Document(metadata={'video_id': 'esQi683XR44', 'title': "How To Bench Press: Layne Norton's Complete Guide", 'author': 'Layne Norton', 'difficulty': 'beginner', 'exercise_type': 'bench_press'}, page_content="Another big mistake I see is rolling your shoulders forward. This tends to go hand in hand with flaring elbows out too wide. Many people tend to roll their shoulders forward as they finish the movement, but this is going to make you stay less tight and has a greater chance of leading to some sort of shoulder injury over the course of your lifting career. Another mistake that coincides with flaring elbows and rolling shoulders is unlocking your shoulder blades. Many people will unlock their shoulder blades as they finish a bench press because they feel it will enable them to lock out more weight, but that's not the case. It will cause you to lose tightness and increase the possibility of injury."),
#  Document(metadata={'video_id': 'esQi683XR44', 'title': "How To Bench Press: Layne Norton's Complete Guide", 'author': 'Layne Norton', 'difficulty': 'beginner', 'exercise_type': 'bench_press'}, page_content="Another mistake I see is people not keeping their feet planted. They have what I call floppy feet. It usually coincides with all the other cues we've talked about of not staying tight. Keep your feet planted on the floor. This will enable you to stay tighter and press more effectively. Now you have the tools to bench press effectively and safely. Remember, lifting weights is a skill, just like any other sport, and the more times you do it, the better you will get at that skill. Start out with light weight, work on your form, and build it up over time. Now, I know it's a lot to remember. There's a lot of cues when it comes to bench pressing, so go back and watch this video over and over until it makes more sense. You may pick up more things every time you watch it. Also, I've broken everything down in detail in this article at bodybuilding.com. For more articles and videos from me and other great contributors, keep coming back to bodybuilding.com.")]

# %% [markdown]
# # Grip Width Lat Puldown

# %% [markdown]
# ## Next step: store these documents in a vector database so you can search them.
# - Remember Chroma from before? You can pass it Documents directly instead of plain text.

# %%
from langchain_chroma import Chroma
from langchain_openai import OpenAIEmbeddings 

embeddings = OpenAIEmbeddings(model='text-embedding-3-small')
#  embeddings tells Chroma how to turn your text into vectors. 
# You're passing it in so Chroma can embed each document's page_content before storing it.

all_docs = jeff_ohp_chunked + jeff_bench_chunked + jeff_squat_chunked + strength_bench_chunked + bodybuilding_bench_chunked
vectorstore = Chroma.from_documents(all_docs, embeddings, persist_directory="/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/chroma_db")
print(vectorstore._collection.count())  # Should show your doc count now
# Out:
# 689

# %% [markdown]
# # Classification model: gpt-4o

# %%
classification_image = base_encoder("/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/data/processed/processed-images/bench_frame_0.jpg")

llm = ChatOpenAI(model='gpt-4o')

response = llm.invoke([

{"role": "user", "content": 
 
[{"type": "text", "text":  """Your job is to analyze images of users working out for proper form, and list the key checkpoints of their to body evaluate. 
  Give me ONLY the bodypart checkpoints. Do NOT include evaluation suggestions. Do NOT include an intro sentence. 
  Output format should be exactly the example below.
**Example**
  Overhead press

  1. Feet & base
  2. Glutes & legs
  3. Core & Ribcage
  4. Shoulder position
  5. Bar path
  6. Head & Neck
  7. Lockout position
  8. Tempo and control
   """},


    {"type": "image_url", "image_url": {"url": f"data:image/jpeg;base64,{classification_image}"}}
    ]}


])

print(response.text)
# Out:
# Bench Press
#
# 1. Feet & base
# 2. Glutes & legs
# 3. Core & Ribcage
# 4. Shoulder position
# 5. Elbow alignment
# 6. Grip & wrist position
# 7. Bar path
# 8. Head & Neck
# 9. Lockout position

# %%
cleaned = clean_classification_text(response)
print(cleaned)
# Out:
# Bench Press     Feet   base    Glutes   legs    Core   Ribcage    Shoulder position    Elbow alignment    Grip   wrist position    Bar path    Head   Neck    Lockout position

# %% [markdown]
# ## Create a dynamic search query LLM

# %% [markdown]
# Here's the flow:
#
# - User asks a question (any fitness question)
# - You search the vectorstore with that question → get back the most relevant chunks
# - Those chunks become the context
# - You pass the context + question to the LLM

# %%
# test_image = base_encoder("/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/data/processed/processed-images/bench_frame_8.jpg")

# user_question = "help me with my bench press"

# results = vectorstore.similarity_search(user_question, k=4)
# context = "\n".join([r.page_content for r in results])

# llm = ChatOpenAI(model='gpt-5')

# response = llm.invoke([
#     {"role": "user", "content": [
#         {"type": "text", "text": "How are the person's feet positioned in this image? Are they flat or is he on his toes?"},
#         {"type": "image_url", "image_url": {"url": f"data:image/jpeg;base64,{test_image}"}}
#     ]}
# ])

# print(response.content)

# %%
# # ANSWER CONTEXT
# Use ONLY the following context when answering a user: 
     
# ---   
# {context}
#  ---
# """

# %%
image_1 = base_encoder("/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/data/processed/processed-images/bench_frame_0.jpg")
image_2 = base_encoder("/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/data/processed/processed-images/bench_frame_1.jpg")
image_3 = base_encoder("/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/data/processed/processed-images/bench_frame_2.jpg")
image_4 = base_encoder("/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/data/processed/processed-images/bench_frame_3.jpg")
image_5 = base_encoder("/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/data/processed/processed-images/bench_frame_4.jpg")
image_6 = base_encoder("/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/data/processed/processed-images/bench_frame_5.jpg")
image_7 = base_encoder("/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/data/processed/processed-images/bench_frame_6.jpg")
image_8 = base_encoder("/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/data/processed/processed-images/bench_frame_7.jpg")
image_9 = base_encoder("/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/data/processed/processed-images/bench_frame_8.jpg")
image_10 = base_encoder("/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/data/processed/processed-images/bench_frame_9.jpg")


retreval_query = cleaned

results = vectorstore.similarity_search(retreval_query, k=4)
context = "\n".join([r.page_content for r in results])

llm = ChatOpenAI(model='gpt-5')

response = llm.invoke([

    {"role": "system", "content": 
     
F"""You are a world-class fitness coach. You have extensive experience in helping weight lifters achieve perfect form an maximum hypertrophy. 
Your job is to analyze images of users lifting weights, offer them advice from your context, and to answer any questions they might have. 
Inspect each image CLOSELY and Carefuly for problems or issues related to best practices in exercise form. Help the user diagnose their incorrect form. 
Be specific about what you observe.

# ANSWER CONTEXT
Use ONLY the following context when answering a user: 
     
---   
{context}
 ---
"""
     
      },

      {"role": "user", "content": 
 
[{"type": "text", "text": """ 
  """},

    {"type": "image_url", "image_url": {"url": f"data:image/jpeg;base64,{image_1}"}},
    {"type": "image_url", "image_url": {"url": f"data:image/jpeg;base64,{image_2}"}},
    {"type": "image_url", "image_url": {"url": f"data:image/jpeg;base64,{image_3}"}},
    {"type": "image_url", "image_url": {"url": f"data:image/jpeg;base64,{image_4}"}},
    {"type": "image_url", "image_url": {"url": f"data:image/jpeg;base64,{image_5}"}},
    {"type": "image_url", "image_url": {"url": f"data:image/jpeg;base64,{image_6}"}},
    {"type": "image_url", "image_url": {"url": f"data:image/jpeg;base64,{image_7}"}},
    {"type": "image_url", "image_url": {"url": f"data:image/jpeg;base64,{image_8}"}},
    {"type": "image_url", "image_url": {"url": f"data:image/jpeg;base64,{image_9}"}},
    {"type": "image_url", "image_url": {"url": f"data:image/jpeg;base64,{image_10}"}}
    
    
    ]}

])

print(response.text)
# Out:
# Great effort. Here’s what I’m seeing and how to fix it using a couple of simple cues.
#
# What I notice
# - Your eyes appear to follow the bar during the rep, and the bar path changes a bit from rep to rep. On some reps you touch lower; on others it’s closer to mid‑chest.
# - Your upper back looks relaxed at times, with the shoulders spreading on the bench instead of being a firm platform.
#
# Cues to clean this up (do these exactly as written)
# - Pick a single point on the ceiling and trap it with your eyes. Do not move your eyes off that point for the entire set.
# - Unrack, then unlock your elbows and lower the bar to your chest. Touch without stopping.
# - Drive the bar back up toward the exact spot on the ceiling your eyes are fixed on. If your eyes don’t move, the bar will go to the same place every rep.
# - Do a set of five reps like this. Rack the bar with locked elbows after the last rep; if you have a spotter, they should cover the move back to the rack.
# - Maximize efficiency by planting your upper back firmly into the bench and using it as a platform as you press. Pinch (adduct) your shoulder blades together and keep them pinched throughout the set.
#
# Quick drill
# - Do another set of five with just the bar, reinforcing eye position and pinched shoulder blades. You’ll feel the bar track the same line every rep.
#
# If you can, send a short side-angle clip next time so I can confirm your upper‑back position and bar path.

# %%
user_question = "my shoulders hurt during lat pulldowns"
""
results = vectorstore.similarity_search(user_question, k=2)
context = results[0].page_content  # the relevant chunk(s)
# then pass context + user_question to the LLM

prompt = ChatPromptTemplate.from_messages([
    ("system", """Use the following context to answer a user question: 
     
     --- 
     {context}
     ---

    You are a {persona}. You understand common form mistakes and why they happen. 
     You prioritize helping users fix their form, but you understand that users also have other goals, like losing weight or building muscle. 

     Keep your first response to 75 tokens or less. Write helpful, informative responses that can be quickly scanned and understood by someone in the gym.
    
     If the context  doesn't contain the answer but is related to exercise or working out (like nutrition, diet, etc.), apologize, and say, 'I don't have that information in my knowledge base yet, but we will soon!' and stop. 
    Do not provide information from your general knowledge. If the question is unrelated to exercise, politely tell the user you can't answer questions unrelated to exercise. 
     
    
    You give actionable feedback like 'squeeze your shoulder blades' instead of 'fix your back'. You explain why your advice matters (injury risk, strength loss, etc.). You are enthusiastic and excited to help users on their fitness journey."""),
    ("human", "{question}")
])

llm = ChatOpenAI(model="gpt-5")
output_parser = StrOutputParser()

chain = prompt | llm | output_parser 

response = chain.invoke({"persona": "helpful and knowledgeable fitness instructor", "context": context, "question": user_question})
print(textwrap.fill(response, width=80))
# Out:
# Sorry, I don't have that information in my knowledge base yet, but we will soon!

# %%
# vectorstore cosine search: use if you need to verify GPT results
results = vectorstore.similarity_search("what muscles should I engage when I bench press", k=2)

for i, doc in enumerate(results, 1):
    print(f"==Results {i}==")
    print(textwrap.fill(doc.page_content, width=80))
    print("\n")
# Out:
# ==Results 1==
# The muscles we'll be targeting here, in order of involvement, are the pec major,
# both the sternal (mid and lower) and clavicular (upper) heads, the triceps
# brachii, the anterior (front) deltoid, and, to a lesser extent, the lats.
# They'll only be active when the shoulder is behind the torso, at the very bottom
# of the press. The primary actions being trained are horizontal shoulder
# adduction, carried out mainly by the pecs and anterior deltoids, some degree of
# shoulder flexion by the upper pecs and front delt, and elbow extension,
# primarily handled by the triceps.  Before we get into the full setup, it's
# important to emphasize that you should only compare your bench strength to your
# starting place and not to anyone else's. Many extraneous factors can contribute
# to performance on this lift, like arm length, rib cage size, muscle origins and
# insertions, lumbar spine mobility, and the size and strength of your upper back
# for creating a stable base of support.
#
#
# ==Results 2==
# The muscles we'll be targeting here, in order of involvement, are the pec major,
# both the sternal (mid and lower) and clavicular (upper) heads, the triceps
# brachii, the anterior (front) deltoid, and, to a lesser extent, the lats.
# They'll only be active when the shoulder is behind the torso, at the very bottom
# of the press. The primary actions being trained are horizontal shoulder
# adduction, carried out mainly by the pecs and anterior deltoids, some degree of
# shoulder flexion by the upper pecs and front delt, and elbow extension,
# primarily handled by the triceps.  Before we get into the full setup, it's
# important to emphasize that you should only compare your bench strength to your
# starting place and not to anyone else's. Many extraneous factors can contribute
# to performance on this lift, like arm length, rib cage size, muscle origins and
# insertions, lumbar spine mobility, and the size and strength of your upper back
# for creating a stable base of support.
