# %% [markdown]
# # How To Get A Huge Bench Press with Perfect Technique
#
# https://www.youtube.com/watch?v=vcBig73ojpE&t=46s

# %%
from youtube_transcript_api import YouTubeTranscriptApi
ytt_api = YouTubeTranscriptApi()

transcript = ytt_api.fetch("_RlRDWO2jfg")

# %%
from rag_pipeline import get_transcript, write_metadata, clean_and_save_transcript
from utils import write_json, read_json
from langchain_openai import ChatOpenAI

# %% [markdown]
# # How To Get A Huge Bench Press with Perfect Technique | Jeff Nippard

# %%
# Pull transcript from Youtube video
transcript = get_transcript(video_id="vcBig73ojpE")
# create the .json filename, add metadata
bench_metadata = write_metadata(video_id="vcBig73ojpE", difficulty="intermediate", title="How To Get A Huge Bench Press with Perfect Technique", author="Jeff Nippard",
                          exercise_type="bench_press", transcript=transcript)
write_json("/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/data/transcripts/nippard_bench_dict.json", bench_metadata) 
# read the transcript and metadata
data = read_json("/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/data/transcripts/nippard_bench_dict.json")
data

# %%
# save cleaned transcript (using GPT) to /processed
cleaned_bench_json = clean_and_save_transcript("/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/data/transcripts/nippard_bench_dict.json", "/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/data/processed/cleaned_nippard_bench_dict")
cleaned_bench_json

# %% [markdown]
# # Build Bigger Shoulders With Perfect Training Technique (The Overhead Press)
# http://youtube.com/watch?v=_RlRDWO2jfg&t=319s
#
# - Jeff Nippard
# - intermediate
# - overhead_press
# - _RlRDWO2jfg

# %%
transcript = get_transcript(video_id="_RlRDWO2jfg")
metadata = write_metadata(video_id="_RlRDWO2jfg", difficulty="intermediate", title="Build Bigger Shoulders With Perfect Training Technique (The Overhead Press)", author="Jeff Nippard",
                          exercise_type="overhead_press", transcript=transcript)
write_json("/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/data/transcripts/nippard_ohp_dict.json", metadata) # create the .json filename, add metadata
data = read_json("/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/data/transcripts/nippard_ohp_dict.json")
data
# Out:
# {'video_id': '_RlRDWO2jfg',
#  'title': 'Build Bigger Shoulders With Perfect Training Technique (The Overhead Press)',
#  'author': 'Jeff Nippard',
#  'difficulty': 'intermediate',
#  'exercise_type': 'overhead_press',
# ...

# %%
ohp = "/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/data/transcripts/nippard_ohp_dict.json"
cleaned_ohp_json = clean_and_save_transcript(ohp, "/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/data/processed/cleaned_nippard_ohp_dict")
cleaned_ohp_json

# %% [markdown]
# # How To Get A Huge Squat With Perfect Technique (Fix Mistakes)
#
# https://www.youtube.com/watch?v=bEv6CCg2BC8
# - Jeff Nippard
# - intermediate
# - squat
# - bEv6CCg2BC8

# %%
transcript = get_transcript(video_id="bEv6CCg2BC8")
metadata = write_metadata(video_id="bEv6CCg2BC8", difficulty="intermediate", title="How To Get A Huge Squat With Perfect Technique (Fix Mistakes)", author="Jeff Nippard",
                          exercise_type="squat", transcript=transcript)
write_json("/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/data/transcripts/nippard_squat_dict.json", metadata) # create the .json filename, add metadata
data = read_json("/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/data/transcripts/nippard_squat_dict.json")
data
# Out:
# {'video_id': 'bEv6CCg2BC8',
#  'title': 'How To Get A Huge Squat With Perfect Technique (Fix Mistakes)',
#  'author': 'Jeff Nippard',
#  'difficulty': 'intermediate',
#  'exercise_type': 'squat',
# ...

# %%
squat = "/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/data/transcripts/nippard_squat_dict.json"
cleaned_squat_json = clean_and_save_transcript(squat, "/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/data/processed/cleaned_nippard_squat_dict")
cleaned_squat_json

# %% [markdown]
# # Learning to Bench Press | The Starting Strength Method
# https://www.youtube.com/watch?v=rxD321l2svE
# - Mark Rippetoe
# - advanced
# - bench press
# - rxD321l2svE

# %%
transcript = get_transcript(video_id="rxD321l2svE")
metadata = write_metadata(video_id="rxD321l2svE", difficulty="advanced", title="Learning to Bench Press | The Starting Strength Method", author="Mark Rippetoe", exercise_type="bench_Press", transcript=transcript)
write_json("/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/data/transcripts/starting_strength_bench_dict.json", metadata)
data = read_json("/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/data/transcripts/starting_strength_bench_dict.json")

# %%
bench_ss = "/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/data/transcripts/starting_strength_bench_dict.json"
cleaned_benchss_json = clean_and_save_transcript(bench_ss, "/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/data/processed/cleaned_starting_strength_bench_dict")
cleaned_benchss_json

# %% [markdown]
# # How To Bench Press: Layne Norton's Complete Guide
# - Layne Norton
# - beginner
# - bench press
# - esQi683XR44

# %%
transcript = get_transcript(video_id="esQi683XR44")
metadata = write_metadata(video_id="esQi683XR44", difficulty="beginner", title="How To Bench Press: Layne Norton's Complete Guide", author="Layne Norton", exercise_type="bench_press", transcript=transcript)
write_json("/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/data/transcripts/bodybuilding_bench_dict.json", metadata)

# %%
bench_bodybuilding = "/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/data/transcripts/bodybuilding_bench_dict.json"
cleaned_bench_bodybuilding_json = clean_and_save_transcript(bench_bodybuilding, "/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/data/processed/cleaned_bodybuilding_bench_dict")
cleaned_bench_bodybuilding_json

# %% [markdown]
# # How To: Incline Barbell Bench Press | 3 GOLDEN RULES! (MADE BETTER!)
# - ScottHermanFitnesss
# - beginner
# - incline bench press
# - SrqOu55lrYU

# %%
transcript = get_transcript(video_id="SrqOu55lrYU")
metadata = write_metadata(video_id="SrqOu55lrYU", difficulty="beginner", title="How To: Incline Barbell Bench Press | 3 GOLDEN RULES! (MADE BETTER!)", author="ScottHermanFitnesss", exercise_type="incline_bench_press", transcript=transcript)
write_json("/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/data/transcripts/incline_bench_dict.json", metadata)
data = read_json("/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/data/transcripts/incline_bench_dict.json")
data

# %%
incline_bench = "/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/data/transcripts/incline_bench_dict.json"
cleaned_incline_bench_json = clean_and_save_transcript(incline_bench, "/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/data/processed/cleaned_incline_bench_dict.json")

# %%
read_json(cleaned_incline_bench_json)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 read_json(cleaned_incline_bench_json)
#
# File ~/Desktop/Ironhack/fitness-form-coach/notebooks/utils.py:26, in read_json(filename)
#      17 def read_json(filename):
#      18     """Load JSON data from a file path.
#      19
#      20     Args:
#    (...)
#      24         Parsed Python object (commonly a dict).
#      25     """
# ---> 26     with open(filename, "r") as f:
#      27         data = json.load(f)
#      28     return data
#
# TypeError: expected str, bytes or os.PathLike object, not NoneType
