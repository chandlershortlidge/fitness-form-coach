# %% [markdown]
# # How To Get A Huge Bench Press with Perfect Technique
#
# https://www.youtube.com/watch?v=vcBig73ojpE&t=46s

# %%
from youtube_transcript_api import YouTubeTranscriptApi
ytt_api = YouTubeTranscriptApi()

transcript = ytt_api.fetch("_RlRDWO2jfg")

# %%
from functions import get_transcript, get_metadata, create_json, load_json

# %%
transcript = get_transcript(video_id="vcBig73ojpE")
metadata = get_metadata(video_id="vcBig73ojpE", difficulty="intermediate", title="How To Get A Huge Bench Press with Perfect Technique", author="Jeff Nippard",
                          exercise_type="bench_press", transcript=transcript)
create_json("nippard_bench_dict.json", metadata) # create the .json filename, add metadata
data = load_json("nippard_bench_dict.json")
data
# Out:
# {'video_id': 'vcBig73ojpE',
#  'title': 'How To Get A Huge Bench Press with Perfect Technique',
#  'author': 'Jeff Nippard',
#  'difficulty': 'intermediate',
#  'exercise_type': 'bench_press',
# ...

# %% [markdown]
# # Build Bigger Shoulders With Perfect Training Technique (The Overhead Press)
# http://youtube.com/watch?v=_RlRDWO2jfg&t=319s
#
# - Jeff Nippard
# - intermediate
# - overhead_press
# - _RlRDWO2jfg

# %%
transcript = get_transcript(video_id="_RlRDWO2jfg")
metadata = get_metadata(video_id="_RlRDWO2jfg", difficulty="intermediate", title="Build Bigger Shoulders With Perfect Training Technique (The Overhead Press)", author="Jeff Nippard",
                          exercise_type="overhead_press", transcript=transcript)
create_json("nippard_ohp_dict.json", metadata) # create the .json filename, add metadata
data = load_json("nippard_ohp_dict.json")
data
# Out:
# {'video_id': '_RlRDWO2jfg',
#  'title': 'Build Bigger Shoulders With Perfect Training Technique (The Overhead Press)',
#  'author': 'Jeff Nippard',
#  'difficulty': 'intermediate',
#  'exercise_type': 'overhead_press',
# ...

# %% [markdown]
# # How To Get A Huge Squat With Perfect Technique (Fix Mistakes)
#
# https://www.youtube.com/watch?v=bEv6CCg2BC8
# - Jeff Nippard
# - intermediate
# - squat
# - bEv6CCg2BC8

# %%
transcript = get_transcript(video_id="bEv6CCg2BC8")
metadata = get_metadata(video_id="bEv6CCg2BC8", difficulty="intermediate", title="Build Bigger Shoulders With Perfect Training Technique (The Overhead Press)", author="Jeff Nippard",
                          exercise_type="squat", transcript=transcript)
create_json("nippard_squat_dict.json", metadata) # create the .json filename, add metadata
data = load_json("nippard_squat_dict.json")
data
# Out:
# {'video_id': 'bEv6CCg2BC8',
#  'title': 'Build Bigger Shoulders With Perfect Training Technique (The Overhead Press)',
#  'author': 'Jeff Nippard',
#  'difficulty': 'intermediate',
#  'exercise_type': 'squat',
# ...
